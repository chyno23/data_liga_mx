# %%
import pandas as pd
data_2023_2024=pd.read_html("https://fbref.com/es/comps/9/horario/Resultados-y-partidos-en-Premier-League", encoding = 'UTF-8')
data = pd.read_htmldata_2022_2023=pd.read_html("https://fbref.com/es/comps/9/2022-2023/horario/Marcadores-y-partidos-de-2022-2023-Premier-League", encoding = 'UTF-8')

data = data[0]
data_2023_2024 = data_2023_2024[0]

#unir dataframes
df = [data,data_2023_2024]
df = pd.concat(df)

#agregar columnas de goles locales y goles visita
df[['Goles Local','Goles Visita']] = df['Marcador'].str.split('–', expand=True)
#Eliminar la columna de Marcador
data = df.drop('Marcador', axis=1)


import re
def extraer_numero(cadena):
    numeros = re.findall(r'\b\d+\b', str(cadena))
    if numeros:
        return int(numeros[0])
    else:
        return None
    
data['Goles Local'] = data['Goles Local'].apply(extraer_numero).fillna(0).astype(int)
data['Goles Visita'] = data['Goles Visita'].apply(extraer_numero).fillna(0).astype(int)

data = data.reset_index(drop=True)

data
# Out:
#      Sem.  Día       Fecha   Hora            Local   xG  xG.1  \
# 0     1.0  Vie  2022-08-05  20:00   Crystal Palace  1.2   1.0
# 1     1.0  Sáb  2022-08-06  12:30           Fulham  1.2   1.2
# 2     1.0  Sáb  2022-08-06  15:00        Tottenham  1.5   0.5
# 3     1.0  Sáb  2022-08-06  15:00    Newcastle Utd  1.7   0.3
# 4     1.0  Sáb  2022-08-06  15:00     Leeds United  0.8   1.3
# ..    ...  ...         ...    ...              ...  ...   ...
# 842  38.0  Dom  2025-05-25  16:00           Fulham  NaN   NaN
# 843  38.0  Dom  2025-05-25  16:00  Nott'ham Forest  NaN   NaN
# 844  38.0  Dom  2025-05-25  16:00   Manchester Utd  NaN   NaN
# 845  38.0  Dom  2025-05-25  16:00           Wolves  NaN   NaN
# 846  38.0  Dom  2025-05-25  16:00        Tottenham  NaN   NaN
#
#            Visitante  Asistencia                      Sedes         Árbitro  \
# 0            Arsenal     25286.0              Selhurst Park  Anthony Taylor
# 1          Liverpool     22207.0             Craven Cottage     Andy Madley
# 2        Southampton     61732.0  Tottenham Hotspur Stadium  Andre Marriner
# 3    Nott'ham Forest     52245.0             St James' Park    Simon Hooper
# 4             Wolves     36347.0                Elland Road    Robert Jones
# ..               ...         ...                        ...             ...
# 842  Manchester City         NaN             Craven Cottage             NaN
# 843          Chelsea         NaN            The City Ground             NaN
# 844      Aston Villa         NaN               Old Trafford             NaN
# 845        Brentford         NaN           Molineux Stadium             NaN
# 846         Brighton         NaN  Tottenham Hotspur Stadium             NaN
#
#      Informe del partido Notas  Goles Local  Goles Visita
# 0    Informe del partido   NaN            0             2
# 1    Informe del partido   NaN            2             2
# 2    Informe del partido   NaN            4             1
# 3    Informe del partido   NaN            2             0
# 4    Informe del partido   NaN            2             1
# ..                   ...   ...          ...           ...
# 842          Cara a cara   NaN            0             0
# 843          Cara a cara   NaN            0             0
# 844          Cara a cara   NaN            0             0
# 845          Cara a cara   NaN            0             0
# 846          Cara a cara   NaN            0             0
#
# [847 rows x 15 columns]

# %%
data = data.drop('xG', axis=1)
data = data.drop('xG.1',axis=1)
data = data.drop('Notas',axis=1)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data = data.drop('xG', axis=1)
#       2 data = data.drop('xG.1',axis=1)
#       3 data = data.drop('Notas',axis=1)
#
# File ~/ML_begin/ml/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/ML_begin/ml/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/ML_begin/ml/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/ML_begin/ml/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['xG'] not found in axis"

# %%
data['Asistencia'] = data['Asistencia'].fillna(False)

# %%
data
# Out:
#      Sem.  Día       Fecha   Hora            Local        Visitante  \
# 0     1.0  Vie  2022-08-05  20:00   Crystal Palace          Arsenal
# 1     1.0  Sáb  2022-08-06  12:30           Fulham        Liverpool
# 2     1.0  Sáb  2022-08-06  15:00        Tottenham      Southampton
# 3     1.0  Sáb  2022-08-06  15:00    Newcastle Utd  Nott'ham Forest
# 4     1.0  Sáb  2022-08-06  15:00     Leeds United           Wolves
# ..    ...  ...         ...    ...              ...              ...
# 842  38.0  Dom  2025-05-25  16:00           Fulham  Manchester City
# 843  38.0  Dom  2025-05-25  16:00  Nott'ham Forest          Chelsea
# 844  38.0  Dom  2025-05-25  16:00   Manchester Utd      Aston Villa
# 845  38.0  Dom  2025-05-25  16:00           Wolves        Brentford
# 846  38.0  Dom  2025-05-25  16:00        Tottenham         Brighton
#
#     Asistencia                      Sedes         Árbitro  \
# 0      25286.0              Selhurst Park  Anthony Taylor
# 1      22207.0             Craven Cottage     Andy Madley
# 2      61732.0  Tottenham Hotspur Stadium  Andre Marriner
# 3      52245.0             St James' Park    Simon Hooper
# 4      36347.0                Elland Road    Robert Jones
# ..         ...                        ...             ...
# 842      False             Craven Cottage             NaN
# 843      False            The City Ground             NaN
# 844      False               Old Trafford             NaN
# 845      False           Molineux Stadium             NaN
# 846      False  Tottenham Hotspur Stadium             NaN
#
#      Informe del partido  Goles Local  Goles Visita
# 0    Informe del partido            0             2
# 1    Informe del partido            2             2
# 2    Informe del partido            4             1
# 3    Informe del partido            2             0
# 4    Informe del partido            2             1
# ..                   ...          ...           ...
# 842          Cara a cara            0             0
# 843          Cara a cara            0             0
# 844          Cara a cara            0             0
# 845          Cara a cara            0             0
# 846          Cara a cara            0             0
#
# [847 rows x 12 columns]

# %%
data[:430]
# Out:
#      Sem.  Día       Fecha   Hora           Local        Visitante Asistencia  \
# 0     1.0  Vie  2022-08-05  20:00  Crystal Palace          Arsenal    25286.0
# 1     1.0  Sáb  2022-08-06  12:30          Fulham        Liverpool    22207.0
# 2     1.0  Sáb  2022-08-06  15:00       Tottenham      Southampton    61732.0
# 3     1.0  Sáb  2022-08-06  15:00   Newcastle Utd  Nott'ham Forest    52245.0
# 4     1.0  Sáb  2022-08-06  15:00    Leeds United           Wolves    36347.0
# ..    ...  ...         ...    ...             ...              ...        ...
# 425  38.0  Dom  2023-05-28  16:30         Everton      Bournemouth    39201.0
# 426  38.0  Dom  2023-05-28  16:30  Leicester City         West Ham    32183.0
# 427  38.0  Dom  2023-05-28  16:30     Aston Villa         Brighton      False
# 428  38.0  Dom  2023-05-28  16:30    Leeds United        Tottenham    36871.0
# 429  38.0  Dom  2023-05-28  16:30       Brentford  Manchester City    17120.0
#
#                            Sedes         Árbitro  Informe del partido  \
# 0                  Selhurst Park  Anthony Taylor  Informe del partido
# 1                 Craven Cottage     Andy Madley  Informe del partido
# 2      Tottenham Hotspur Stadium  Andre Marriner  Informe del partido
# 3                 St James' Park    Simon Hooper  Informe del partido
# 4                    Elland Road    Robert Jones  Informe del partido
# ..                           ...             ...                  ...
# 425                Goodison Park  Stuart Attwell  Informe del partido
# 426           King Power Stadium    Simon Hooper  Informe del partido
# 427                   Villa Park     David Coote  Informe del partido
# 428                  Elland Road  Anthony Taylor  Informe del partido
# 429  Brentford Community Stadium     John Brooks  Informe del partido
#
#      Goles Local  Goles Visita
# 0              0             2
# 1              2             2
# 2              4             1
# 3              2             0
# 4              2             1
# ..           ...           ...
# 425            1             0
# 426            2             1
# 427            2             1
# 428            1             4
# 429            1             0
#
# [430 rows x 12 columns]

# %%
data = data[(data["Sem."] != 0) & (data["Goles Local"] != 0)]
