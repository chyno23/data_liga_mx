# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_html("https://fbref.com/es/comps/12/shooting/Estadisticas-de-La-Liga", encoding='UTF-8')

# %%
data=data[0]

# %%
pd.concat([data['Unnamed: 0_level_0'],data['Estándar']],axis=1).sort_values(by='Gls.').reset_index(drop=True)
# Out:
#              Equipo  Gls.  Dis  DaP  % de TT   T/90  TalArc/90   G/T  \
# 0             Cádiz    15  195   58     29.7   9.29       2.76  0.07
# 1            Alavés    16  265   72     27.2  12.62       3.43  0.05
# 2    Rayo Vallecano    18  253   92     36.4  12.65       4.60  0.05
# 3          Mallorca    19  229   69     30.1  10.90       3.29  0.08
# 4        Celta Vigo    20  274   80     29.2  13.05       3.81  0.07
# 5           Granada    20  219   75     34.2  10.43       3.57  0.08
# 6           Almería    21  262   86     32.8  12.48       4.10  0.08
# 7        Las Palmas    21  207   65     31.4   9.86       3.10  0.09
# 8           Sevilla    24  313   94     30.0  14.90       4.48  0.07
# 9             Betis    24  291   83     28.5  13.86       3.95  0.08
# 10          Osasuna    25  228   71     31.1  11.40       3.55  0.09
# 11           Getafe    26  229   84     36.7  11.45       4.20  0.09
# 12         Valencia    27  197   69     35.0   9.38       3.29  0.12
# ...
