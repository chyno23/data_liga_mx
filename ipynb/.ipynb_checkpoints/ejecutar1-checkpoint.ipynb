# %%
from extr_urls import extr_url_primer

# %%
import pandas as pd
import numpy as np

def extr_url_primer(urlpath):

    data = pd.read_html('https://fbref.com/es/comps/9/2019-2020/horario/Marcadores-y-partidos-de-2019-2020-Premier-League')
    for i in range(0,5):
        urlname = '20'+str(i)'-'+'20'+str(i+1)'/horario/Marcadores-y-partidos-de-202'+str(i)+'-202'+str(i+1)+'-Premier-League'
        url = urlpath + urlname 

        sesons_data = pd.read_html(url)
        sesons_data = sesons_data[0]
        data = pd.concat([data, sesons_data],axis=0)

# %%
urlpath = 'https://fbref.com/es/comps/9/'

# %%
extr_url_primer(urlpath)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 extr_url_primer(urlpath)
#
# Cell In[17], line 13, in extr_url_primer(urlpath)
#      11 sesons_data = pd.read_html(url)
#      12 sesons_data = sesons_data[0]
# ---> 13 data = pd.concat([data, sesons_data],axis=0)
#
# File ~/ML_begin/ml/lib/python3.12/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
# ...

# %%
import pandas as pd
urlpath = 'https://fbref.com/es/comps/9/'
data = pd.read_html('https://fbref.com/es/comps/9/2019-2020/horario/Marcadores-y-partidos-de-2019-2020-Premier-League')
for i in range(0,5):
    urlname = '20'+str(i)+'-'+'20'+str(i+1)+'/horario/Marcadores-y-partidos-de-202'+str(i)+'-202'+str(i+1)+'-Premier-League'
    url = urlpath + urlname 

    sesons_data = pd.read_html(url,encoding='UTF-8')
    sesons_data = sesons_data[0]
    data = pd.concat([data, sesons_data],axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 9
#       7 sesons_data = pd.read_html(url,encoding='UTF-8')
#       8 sesons_data = sesons_data[0]
# ----> 9 data = pd.concat([data, sesons_data],axis=0)
#
# File ~/ML_begin/ml/lib/python3.12/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# ...

# %%
url
# Out:
# 'https://fbref.com/es/comps/9/2019-2020/horario/Marcadores-y-partidos-de-2023-2024-Premier-League'

# %%
import pandas as pd
import time

urlpath = 'https://fbref.com/es/comps/9/'
data = pd.read_html('https://fbref.com/es/comps/9/2019-2020/horario/Marcadores-y-partidos-de-2019-2020-Premier-League')
data = data[0]
for i in range(0, 2):
    urlname = '20' + str(i) + '-' + '20' + str(i + 1) + '/horario/Marcadores-y-partidos-de-202' + str(i) + '-202' + str(i + 1) + '-Premier-League'
    url = urlpath + urlname


    seasons_data = pd.read_html(url)
    seadons_data = seasons_data[0]
    data = pd.concat([data, seasons_data], axis=0)
    time.sleep(5)  # Esperar 5 segundos entre solicitudes

data.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       2 import time
#       4 urlpath = 'https://fbref.com/es/comps/9/'
# ----> 5 data = pd.read_html('https://fbref.com/es/comps/9/2019-2020/horario/Marcadores-y-partidos-de-2019-2020-Premier-League')
#       6 data = data[0]
#       7 for i in range(0, 2):
#
# File ~/ML_begin/ml/lib/python3.12/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
# ...

# %%
from extr_urls import extr_url_primer

# %%
urlpath = 'https://fbref.com/es/comps/9/'
extr_url_primer(urlpath)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 urlpath = 'https://fbref.com/es/comps/9/'
# ----> 2 extr_url_primer(urlpath)
#
# File ~/ML_begin/data_liga_mx/ipynb/extr_urls.py:6, in extr_url_primer(urlpath)
#       4 def extr_url_primer(urlpath):
# ----> 6     data = pd.read_html('https://fbref.com/es/comps/9/2019-2020/horario/Marcadores-y-partidos-de-2019-2020-Premier-League')
#       7     data = data[0]
#       8     for i in range(0, 2):
#
# File ~/ML_begin/ml/lib/python3.12/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 data = pd.read_html('https://fbref.com/es/comps/9/2019-2020/horario/Marcadores-y-partidos-de-2019-2020-Premier-League')
#
# File ~/ML_begin/ml/lib/python3.12/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# ...
