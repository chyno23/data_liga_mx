# %%
import pandas as pd
data = pd.read_html("https://fbref.com/es/comps/31/2022-2023/Estadisticas-2022-2023-Liga-MX", encoding='UTF-8')

# %%
data=data[4]

# %%
data['Rendimiento']
# Out:
#     Gls.  Ass  G+A  G-TP  TP  TPint  TA  TR
# 0     73   53  126    68   5      6  63   0
# 1     42   26   68    38   4      5  74   6
# 2     27   20   47    23   4      5  78   4
# 3     46   32   78    39   7      8  79   8
# 4     34   21   55    32   2      5  86   8
# 5     44   31   75    39   5      8  78   7
# 6     46   33   79    44   2      2  76  12
# 7     33   21   54    32   1      3  83   4
# 8     63   48  111    58   5      9  80   2
# 9     33   22   55    30   3      4  90   2
# 10    58   39   97    53   5      6  68   4
# 11    50   41   91    46   4      4  95   2
# 12    33   24   57    29   4      6  83   3
# 13    61   37   98    51  10     10  66   6
# 14    32   17   49    27   5      7  85   7
# 15    60   42  102    49  11     11  73   8
# 16    43   32   75    39   4      5  90  10
# 17    44   34   78    40   4      5  85   8
