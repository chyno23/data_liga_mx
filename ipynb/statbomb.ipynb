# %%
# !pip install statsbombpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 916.5 kB/s eta 0:00:0031m2.7 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 1.1 MB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 796.7 kB/s eta 0:00:001m1.9 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.0 MB/s eta 0:00:00
# ...

# %%
from statsbombpy import sb

# %%
competencia=sb.competitions()
# Out:
# /home/emmanuel/ML_begin/ml/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
competencia[competencia['competition_name']=='Premier League']
# Out:
#     competition_id  season_id country_name competition_name  \
# 64               2         27      England   Premier League
# 65               2         44      England   Premier League
#
#    competition_gender  competition_youth  competition_international  \
# 64               male              False                      False
# 65               male              False                      False
#
#    season_name               match_updated        match_updated_360  \
# 64   2015/2016  2024-06-12T07:43:56.243851  2021-06-13T16:17:31.694
# 65   2003/2004  2024-03-08T14:49:13.195793  2021-06-13T16:17:31.694
#
#    match_available_360             match_available
# 64                None  2024-06-12T07:43:56.243851
# 65                None  2024-03-08T14:49:13.195793

# %%
sb.matches(competition_id=2, season_id=27)
# Out:
# /home/emmanuel/ML_begin/ml/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#      match_id  match_date      kick_off               competition     season  \
# 0     3754058  2016-01-02  16:00:00.000  England - Premier League  2015/2016
# 1     3754245  2015-10-17  16:00:00.000  England - Premier League  2015/2016
# 2     3754136  2015-12-19  18:30:00.000  England - Premier League  2015/2016
# 3     3754037  2016-04-30  16:00:00.000  England - Premier League  2015/2016
# 4     3754039  2016-02-13  16:00:00.000  England - Premier League  2015/2016
# ..        ...         ...           ...                       ...        ...
# 375   3754020  2015-08-17  21:00:00.000  England - Premier League  2015/2016
# 376   3754267  2015-08-15  16:00:00.000  England - Premier League  2015/2016
# 377   3754141  2015-08-09  14:30:00.000  England - Premier League  2015/2016
# ...

# %%
sb.matches(competition_id=9, season_id=281).columns
# Out:
# /home/emmanuel/ML_begin/ml/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Index(['match_id', 'match_date', 'kick_off', 'competition', 'season',
#        'home_team', 'away_team', 'home_score', 'away_score', 'match_status',
#        'match_status_360', 'last_updated', 'last_updated_360', 'match_week',
#        'competition_stage', 'stadium', 'referee', 'home_managers',
#        'away_managers', 'data_version', 'shot_fidelity_version',
#        'xy_fidelity_version'],
#       dtype='object')

# %%
sb.matches(competition_id=9, season_id=281)
# Out:
# /home/emmanuel/ML_begin/ml/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     match_id  match_date      kick_off              competition     season  \
# 0    3895302  2024-04-14  17:30:00.000  Germany - 1. Bundesliga  2023/2024
# 1    3895292  2024-04-06  15:30:00.000  Germany - 1. Bundesliga  2023/2024
# 2    3895333  2024-05-05  18:30:00.000  Germany - 1. Bundesliga  2023/2024
# 3    3895340  2024-05-12  20:30:00.000  Germany - 1. Bundesliga  2023/2024
# 4    3895348  2024-05-18  16:30:00.000  Germany - 1. Bundesliga  2023/2024
# 5    3895286  2024-03-30  16:30:00.000  Germany - 1. Bundesliga  2023/2024
# 6    3895220  2024-02-03  16:30:00.000  Germany - 1. Bundesliga  2023/2024
# 7    3895250  2024-02-23  21:30:00.000  Germany - 1. Bundesliga  2023/2024
# 8    3895266  2024-03-10  20:30:00.000  Germany - 1. Bundesliga  2023/2024
# ...

# %%
sorted(sb.events(match_id=3895302).columns)
# Out:
# /home/emmanuel/ML_begin/ml/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# ['50_50',
#  'bad_behaviour_card',
#  'ball_receipt_outcome',
#  'ball_recovery_recovery_failure',
#  'block_deflection',
#  'block_save_block',
#  'carry_end_location',
#  'clearance_aerial_won',
#  'clearance_body_part',
#  'clearance_head',
#  'clearance_left_foot',
#  'clearance_right_foot',
#  'counterpress',
#  'dribble_nutmeg',
#  'dribble_outcome',
#  'duel_outcome',
#  'duel_type',
#  'duration',
#  'foul_committed_advantage',
#  'foul_committed_card',
#  'foul_committed_penalty',
#  'foul_won_advantage',
#  'foul_won_defensive',
#  'foul_won_penalty',
#  'goalkeeper_body_part',
#  'goalkeeper_end_location',
#  'goalkeeper_outcome',
#  'goalkeeper_position',
#  'goalkeeper_technique',
#  'goalkeeper_type',
#  'id',
#  'index',
#  'injury_stoppage_in_chain',
#  'interception_outcome',
#  'location',
# ...

# %%
df_match = sb.events(match_id=3895302)
df_match = df_match[['timestamp','team','type','minute','location','pass_end_location','player']]
df_match = df_match.sort_values(['minute','timestamp'])
df_match
# Out:
# /home/emmanuel/ML_begin/ml/lib/python3.12/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#          timestamp              team         type  minute       location  \
# 0     00:00:00.000  Bayer Leverkusen  Starting XI       0            NaN
# 1     00:00:00.000     Werder Bremen  Starting XI       0            NaN
# 2     00:00:00.000  Bayer Leverkusen   Half Start       0            NaN
# 3     00:00:00.000     Werder Bremen   Half Start       0            NaN
# 6     00:00:03.417     Werder Bremen         Pass       0   [61.0, 40.1]
# ...            ...               ...          ...     ...            ...
# 3786  00:44:22.844     Werder Bremen     Pressure      89   [24.4, 23.9]
# 4119  00:44:25.079  Bayer Leverkusen         Shot      89  [106.4, 48.8]
# 4153  00:44:25.897     Werder Bremen  Goal Keeper      89    [5.4, 36.1]
# ...

# %%
df_match['type'].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt*', 'Carry',
#        'Pressure', 'Miscontrol', 'Dribble', 'Duel', 'Interception',
#        'Ball Recovery', 'Dispossessed', 'Block', 'Foul Committed',
#        'Foul Won', 'Error', 'Shot', 'Goal Keeper', 'Injury Stoppage',
#        'Referee Ball-Drop', '50/50', 'Clearance', 'Offside',
#        'Dribbled Past', 'Player Off', 'Player On', 'Substitution',
#        'Bad Behaviour', 'Half End', 'Tactical Shift', 'Shield'],
#       dtype=object)

# %%
df_match[df_match['type']=='Shot']
# Out:
#          timestamp              team  type  minute       location  \
# 4093  00:06:48.773     Werder Bremen  Shot       6  [100.4, 35.1]
# 4094  00:07:40.953  Bayer Leverkusen  Shot       7  [114.6, 33.5]
# 4095  00:11:08.471     Werder Bremen  Shot      11  [106.2, 55.8]
# 4096  00:13:16.073  Bayer Leverkusen  Shot      13  [113.9, 47.4]
# 4097  00:16:00.956  Bayer Leverkusen  Shot      16   [89.2, 42.5]
# 4098  00:16:31.596  Bayer Leverkusen  Shot      16  [110.2, 32.6]
# 4099  00:18:28.225     Werder Bremen  Shot      18  [105.4, 45.1]
# 4100  00:24:27.217  Bayer Leverkusen  Shot      24  [108.0, 40.0]
# 4101  00:27:46.504  Bayer Leverkusen  Shot      27  [101.5, 47.5]
# 4102  00:28:21.806  Bayer Leverkusen  Shot      28  [116.3, 46.0]
# 4103  00:28:23.060  Bayer Leverkusen  Shot      28  [116.3, 43.3]
# 4104  00:34:51.122  Bayer Leverkusen  Shot      34  [109.4, 44.9]
# 4105  00:37:40.441  Bayer Leverkusen  Shot      37  [113.1, 27.5]
# ...
