# %%
import pandas as pd

# %%
data = pd.read_html('https://fbref.com/es/comps/9/2022-2023/gca/Estadisticas-2022-2023-Premier-League',encoding='UTF-8',header=1)

# %%
data[0].sort_values(by="Dis",ascending=False)
# Out:
#              Equipo  PL  90 s   ACT  SCA90  PassLive  PassDead  HASTA  Dis  \
# 14    Newcastle Utd  27  38.0  1008  26.53       690       110     62   77
# 12  Manchester City  24  38.0  1099  28.92       826        81     53   76
# 11        Liverpool  28  38.0  1046  27.53       778        85     56   75
# 0           Arsenal  26  38.0  1045  27.50       776        78     57   73
# 4          Brighton  29  38.0  1075  28.29       819        73     81   63
# 13   Manchester Utd  26  38.0  1051  27.66       840        58     46   63
# 18         West Ham  25  38.0   817  21.50       586        81     40   60
# 17        Tottenham  29  38.0   910  23.95       692        60     46   55
# 7           Everton  28  38.0   735  19.34       493        84     39   54
# 8            Fulham  29  38.0   751  19.76       528        78     29   54
# 9      Leeds United  29  38.0   783  20.61       535        99     32   54
# ...

# %%
data = pd.read_html('https://www.fichajes.com/inglaterra/premier-league/estadistica-jugadores/regates-completados',encoding='UTF8')

# %%
data[0]
# Out:
#      #       Jugadores  Total  por partido
# 0    1        M. Kudus     42          3.2
# 1    2         J. Doku     41          2.9
# 2    3       A. Fatawu     29          2.6
# 3    4       I. Ndiaye     40          2.4
# 4    5         Savinho     35          2.3
# 5    6      A. Semenyo     39          2.3
# 6    7       J. Sancho     26          2.2
# 7    8   Matheus Cunha     38          2.1
# 8    9          E. Eze     29          2.1
# 9   10         B. Saka     33          2.1
# 10  11   O. Hutchinson     34          2.0
# 11  12       K. Mitoma     35          1.9
# 12  13       M. Rogers     34          1.9
# 13  14        J. Bowen     33          1.8
# 14  15        A. Broja      5          1.7
# 15  16    R. Aït-Nouri     28          1.6
# 16  17       J. Ramsey     16          1.6
# 17  18  A. Wan-Bissaka     27          1.6
# 18  18   Mohamed Salah     27          1.6
# 19  20       K. Mainoo     19          1.6
